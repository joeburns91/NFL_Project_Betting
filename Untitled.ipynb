# %%
import pandas as pd
import numpy as np

# %%
# import all of our play_by_play data
data = pd.read_csv('play_by_play.csv')

def dynamic_window_ewma(x):
    """
    Calculate rolling exponentially weighted EPA with a dynamic window size
    """
    values = np.zeros(len(x))
    for i, (_, row) in enumerate(x.iterrows()):
        epa = x.epa_shifted[:i+1]
        if row.week > 10:
            values[i] = epa.ewm(min_periods=1, span=row.week).mean().values[-1]
        else:
            values[i] = epa.ewm(min_periods=1, span=10).mean().values[-1]
            
    return pd.Series(values, index=x.index)

# seperate EPA in to rushing offense, rushing defense, passing offense, passing defense for each team
rushing_offense_epa = data.loc[data['rush_attempt'] == 1, :]\
.groupby(['posteam', 'season', 'week'], as_index=False)['epa'].mean()

rushing_defense_epa = data.loc[data['rush_attempt'] == 1, :]\
.groupby(['defteam', 'season', 'week'], as_index=False)['epa'].mean()

passing_offense_epa = data.loc[data['pass_attempt'] == 1, :]\
.groupby(['posteam', 'season', 'week'], as_index=False)['epa'].mean()

passing_defense_epa = data.loc[data['pass_attempt'] == 1, :]\
.groupby(['defteam', 'season', 'week'], as_index=False)['epa'].mean()

# lag EPA one period back to give us EPA going INTO a game.
rushing_offense_epa['epa_shifted'] = rushing_offense_epa.groupby('posteam')['epa'].shift()
rushing_defense_epa['epa_shifted'] = rushing_defense_epa.groupby('defteam')['epa'].shift()
passing_offense_epa['epa_shifted'] = passing_offense_epa.groupby('posteam')['epa'].shift()
passing_defense_epa['epa_shifted'] = passing_defense_epa.groupby('defteam')['epa'].shift()

# In each case, calculate EWMA with a static window and dynamic window and assign it as a column 
# However we will use a dynamic window for the model

rushing_offense_epa['ewma'] = rushing_offense_epa.groupby('posteam')['epa_shifted']\
.transform(lambda x: x.ewm(min_periods=1, span=10).mean())

rushing_offense_epa['ewma_dynamic_window'] = rushing_offense_epa.groupby('posteam')\
.apply(dynamic_window_ewma).values

rushing_defense_epa['ewma'] = rushing_defense_epa.groupby('defteam')['epa_shifted']\
.transform(lambda x: x.ewm(min_periods=1, span=10).mean())

rushing_defense_epa['ewma_dynamic_window'] = rushing_defense_epa.groupby('defteam')\
.apply(dynamic_window_ewma).values

passing_offense_epa['ewma'] = passing_offense_epa.groupby('posteam')['epa_shifted']\
.transform(lambda x: x.ewm(min_periods=1, span=10).mean())

passing_offense_epa['ewma_dynamic_window'] = passing_offense_epa.groupby('posteam')\
.apply(dynamic_window_ewma).values

passing_defense_epa['ewma'] = passing_defense_epa.groupby('defteam')['epa_shifted']\
.transform(lambda x: x.ewm(min_periods=1, span=10).mean())

passing_defense_epa['ewma_dynamic_window'] = passing_defense_epa.groupby('defteam')\
.apply(dynamic_window_ewma).values

#Merge all the data together
offense_epa = rushing_offense_epa.merge(passing_offense_epa, on=['posteam', 'season', 'week'], suffixes=('_rushing', '_passing'))\
.rename(columns={'posteam': 'team'})
defense_epa = rushing_defense_epa.merge(passing_defense_epa, on=['defteam', 'season', 'week'], suffixes=('_rushing', '_passing'))\
.rename(columns={'defteam': 'team'})
epa = offense_epa.merge(defense_epa, on=['team', 'season', 'week'], suffixes=('_offense', '_defense'))

#remove the first season of data because we are doing EWMA
epa = epa.loc[epa['season'] != epa['season'].unique()[0], :]

epa = epa.reset_index(drop=True)

epa.head()
# Out:
# c:\users\joebu\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3524: DtypeWarning: Columns (37,38,46,180,181,183,184,190,191,194,195,198,199,204,205,206,207,208,209,210,211,212,213,214,215,219,220,221,223,225,227,234,235,236,237,238,239,249,250,254,255,256,261,263,264,267,268,269,270,284,285,293,294,295,296,297,300,302,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   team  season  week  epa_rushing_offense  epa_shifted_rushing_offense  \
# 0  ARI    2000     1            -0.345669                    -0.068545
# 1  ARI    2000     2            -0.276743                    -0.345669
# 2  ARI    2000     4            -0.334533                    -0.276743
# 3  ARI    2000     5            -0.016838                    -0.334533
# 4  ARI    2000     6            -0.038473                    -0.016838
#
#    ewma_rushing_offense  ewma_dynamic_window_rushing_offense  \
# 0             -0.109518                            -0.109518
# 1             -0.153920                            -0.153920
# 2             -0.176871                            -0.176871
# 3             -0.206184                            -0.206184
# 4             -0.171124                            -0.171124
#
#    epa_passing_offense  epa_shifted_passing_offense  ewma_passing_offense  \
# 0             0.019830                     0.056256             -0.172588
# 1             0.558977                     0.019830             -0.136410
# 2            -0.264054                     0.558977             -0.006468
# 3             0.049141                    -0.264054             -0.054359
# 4             0.101830                     0.049141             -0.035195
#
#    ewma_dynamic_window_passing_offense  epa_rushing_defense  \
# 0                            -0.172588             0.166199
# 1                            -0.136410            -0.065981
# 2                            -0.006468            -0.018524
# 3                            -0.054359             0.004625
# 4                            -0.035195             0.086308
#
#    epa_shifted_rushing_defense  ewma_rushing_defense  \
# 0                     0.363190              0.086016
# 1                     0.166199              0.101092
# 2                    -0.065981              0.069872
# 3                    -0.018524              0.053437
# 4                     0.004625              0.044399
#
#    ewma_dynamic_window_rushing_defense  epa_passing_defense  \
# 0                             0.086016            -0.009200
# 1                             0.101092             0.283460
# 2                             0.069872             0.500345
# 3                             0.053437             0.058499
# 4                             0.044399            -0.063633
#
#    epa_shifted_passing_defense  ewma_passing_defense  \
# 0                     0.269840              0.115978
# 1                    -0.009200              0.092441
# 2                     0.283460              0.128136
# 3                     0.500345              0.197339
# 4                     0.058499              0.171631
#
#    ewma_dynamic_window_passing_defense
# 0                             0.115978
# 1                             0.092441
# 2                             0.128136
# 3                             0.197339
# 4                             0.171631

# %%
epa['team'].unique()
# Out:
# array(['ARI', 'ATL', 'BAL', 'BUF', 'CAR', 'CHI', 'CIN', 'CLE', 'DAL',
#        'DEN', 'DET', 'GB', 'HOU', 'IND', 'JAX', 'KC', 'LA', 'LAC', 'LV',
#        'MIA', 'MIN', 'NE', 'NO', 'NYG', 'NYJ', 'PHI', 'PIT', 'SEA', 'SF',
#        'TB', 'TEN', 'WAS'], dtype=object)

# %%
game_data = pd.read_csv('games_data.csv')

# %%
print(game_data.info())
game_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6137 entries, 0 to 6136
# Data columns (total 46 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        6137 non-null   int64
#  1   game_id           6137 non-null   object
#  2   season            6137 non-null   int64
#  3   game_type         6137 non-null   object
#  4   week              6137 non-null   int64
#  5   gameday           6137 non-null   object
#  6   weekday           6137 non-null   object
#  7   gametime          5878 non-null   object
#  8   away_team         6137 non-null   object
#  9   away_score        6137 non-null   int64
#  10  home_team         6137 non-null   object
#  11  home_score        6137 non-null   int64
#  12  location          6137 non-null   object
#  13  result            6137 non-null   int64
#  14  total             6137 non-null   int64
#  15  overtime          6137 non-null   int64
#  16  old_game_id       6137 non-null   int64
#  17  gsis              6111 non-null   float64
#  18  nfl_detail_id     272 non-null    object
#  19  pfr               6137 non-null   object
#  20  pff               4292 non-null   float64
#  21  espn              6137 non-null   int64
#  22  away_rest         6137 non-null   int64
#  23  home_rest         6137 non-null   int64
#  24  away_moneyline    4156 non-null   float64
#  25  home_moneyline    4156 non-null   float64
#  26  spread_line       6137 non-null   float64
#  27  away_spread_odds  4156 non-null   float64
#  28  home_spread_odds  4156 non-null   float64
#  29  total_line        6137 non-null   float64
#  30  under_odds        4153 non-null   float64
#  31  over_odds         4153 non-null   float64
#  32  div_game          6137 non-null   int64
#  33  roof              6112 non-null   object
#  34  surface           6137 non-null   object
#  35  temp              4365 non-null   float64
#  36  wind              4365 non-null   float64
#  37  away_qb_id        6137 non-null   object
#  38  home_qb_id        6137 non-null   object
#  39  away_qb_name      6137 non-null   object
#  40  home_qb_name      6137 non-null   object
#  41  away_coach        6137 non-null   object
#  42  home_coach        6137 non-null   object
#  43  referee           5852 non-null   object
#  44  stadium_id        6137 non-null   object
#  45  stadium           6137 non-null   object
# dtypes: float64(12), int64(13), object(21)
# memory usage: 2.2+ MB
# None
#    Unnamed: 0          game_id  season game_type  week     gameday weekday  \
# 0           0  1999_01_MIN_ATL    1999       REG     1  1999-09-12  Sunday
# 1           1   1999_01_KC_CHI    1999       REG     1  1999-09-12  Sunday
# 2           2  1999_01_PIT_CLE    1999       REG     1  1999-09-12  Sunday
# 3           3   1999_01_OAK_GB    1999       REG     1  1999-09-12  Sunday
# 4           4  1999_01_BUF_IND    1999       REG     1  1999-09-12  Sunday
#
#   gametime away_team  away_score  ...  wind  away_qb_id  home_qb_id  \
# 0      NaN       MIN          17  ...   NaN  00-0003761  00-0002876
# 1      NaN        KC          17  ...  12.0  00-0006300  00-0010560
# 2      NaN       PIT          43  ...  12.0  00-0015700  00-0004230
# 3      NaN       OAK          24  ...  10.0  00-0005741  00-0005106
# 4      NaN       BUF          14  ...   NaN  00-0005363  00-0010346
#
#          away_qb_name    home_qb_name          away_coach    home_coach  \
# 0  Randall Cunningham  Chris Chandler        Dennis Green    Dan Reeves
# 1         Elvis Grbac  Shane Matthews  Gunther Cunningham   Dick Jauron
# 2     Kordell Stewart       Ty Detmer         Bill Cowher  Chris Palmer
# 3         Rich Gannon     Brett Favre          Jon Gruden    Ray Rhodes
# 4         Doug Flutie  Peyton Manning       Wade Phillips      Jim Mora
#
#          referee stadium_id                   stadium
# 0   Gerry Austin      ATL00              Georgia Dome
# 1   Phil Luckett      CHI98             Soldier Field
# 2    Bob McElwee      CLE00  Cleveland Browns Stadium
# 3  Tony Corrente      GNB00             Lambeau Field
# 4       Ron Blum      IND99                  RCA Dome
#
# [5 rows x 46 columns]

# %%
df = game_data.merge(epa.rename(columns={'team': 'home_team'}), on=['home_team', 'season', 'week'])\
.merge(epa.rename(columns={'team': 'away_team'}), on=['away_team', 'season', 'week'], suffixes=('_home', '_away'))
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5047 entries, 0 to 5046
# Data columns (total 78 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Unnamed: 0                                5047 non-null   int64
#  1   game_id                                   5047 non-null   object
#  2   season                                    5047 non-null   int64
#  3   game_type                                 5047 non-null   object
#  4   week                                      5047 non-null   int64
#  5   gameday                                   5047 non-null   object
#  6   weekday                                   5047 non-null   object
#  7   gametime                                  5047 non-null   object
#  8   away_team                                 5047 non-null   object
#  9   away_score                                5047 non-null   int64
#  10  home_team                                 5047 non-null   object
#  11  home_score                                5047 non-null   int64
#  12  location                                  5047 non-null   object
#  13  result                                    5047 non-null   int64
#  14  total                                     5047 non-null   int64
#  15  overtime                                  5047 non-null   int64
#  16  old_game_id                               5047 non-null   int64
#  17  gsis                                      5021 non-null   float64
#  18  nfl_detail_id                             272 non-null    object
#  19  pfr                                       5047 non-null   object
#  20  pff                                       3750 non-null   float64
#  21  espn                                      5047 non-null   int64
#  22  away_rest                                 5047 non-null   int64
#  23  home_rest                                 5047 non-null   int64
#  24  away_moneyline                            3637 non-null   float64
#  25  home_moneyline                            3637 non-null   float64
#  26  spread_line                               5047 non-null   float64
#  27  away_spread_odds                          3637 non-null   float64
#  28  home_spread_odds                          3637 non-null   float64
#  29  total_line                                5047 non-null   float64
#  30  under_odds                                3634 non-null   float64
#  31  over_odds                                 3634 non-null   float64
#  32  div_game                                  5047 non-null   int64
#  33  roof                                      5022 non-null   object
#  34  surface                                   5047 non-null   object
#  35  temp                                      3544 non-null   float64
#  36  wind                                      3544 non-null   float64
#  37  away_qb_id                                5047 non-null   object
#  38  home_qb_id                                5047 non-null   object
#  39  away_qb_name                              5047 non-null   object
#  40  home_qb_name                              5047 non-null   object
#  41  away_coach                                5047 non-null   object
#  42  home_coach                                5047 non-null   object
#  43  referee                                   4762 non-null   object
#  44  stadium_id                                5047 non-null   object
#  45  stadium                                   5047 non-null   object
#  46  epa_rushing_offense_home                  5047 non-null   float64
#  47  epa_shifted_rushing_offense_home          5046 non-null   float64
#  48  ewma_rushing_offense_home                 5046 non-null   float64
#  49  ewma_dynamic_window_rushing_offense_home  5046 non-null   float64
#  50  epa_passing_offense_home                  5047 non-null   float64
#  51  epa_shifted_passing_offense_home          5046 non-null   float64
#  52  ewma_passing_offense_home                 5046 non-null   float64
#  53  ewma_dynamic_window_passing_offense_home  5046 non-null   float64
#  54  epa_rushing_defense_home                  5047 non-null   float64
#  55  epa_shifted_rushing_defense_home          5046 non-null   float64
#  56  ewma_rushing_defense_home                 5046 non-null   float64
#  57  ewma_dynamic_window_rushing_defense_home  5046 non-null   float64
#  58  epa_passing_defense_home                  5047 non-null   float64
#  59  epa_shifted_passing_defense_home          5046 non-null   float64
#  60  ewma_passing_defense_home                 5046 non-null   float64
#  61  ewma_dynamic_window_passing_defense_home  5046 non-null   float64
#  62  epa_rushing_offense_away                  5047 non-null   float64
#  63  epa_shifted_rushing_offense_away          5047 non-null   float64
#  64  ewma_rushing_offense_away                 5047 non-null   float64
#  65  ewma_dynamic_window_rushing_offense_away  5047 non-null   float64
#  66  epa_passing_offense_away                  5047 non-null   float64
#  67  epa_shifted_passing_offense_away          5047 non-null   float64
#  68  ewma_passing_offense_away                 5047 non-null   float64
#  69  ewma_dynamic_window_passing_offense_away  5047 non-null   float64
#  70  epa_rushing_defense_away                  5047 non-null   float64
#  71  epa_shifted_rushing_defense_away          5047 non-null   float64
#  72  ewma_rushing_defense_away                 5047 non-null   float64
#  73  ewma_dynamic_window_rushing_defense_away  5047 non-null   float64
#  74  epa_passing_defense_away                  5047 non-null   float64
#  75  epa_shifted_passing_defense_away          5047 non-null   float64
#  76  ewma_passing_defense_away                 5047 non-null   float64
#  77  ewma_dynamic_window_passing_defense_away  5047 non-null   float64
# dtypes: float64(44), int64(13), object(21)
# memory usage: 3.0+ MB
# None
#    Unnamed: 0          game_id  season game_type  week     gameday weekday  \
# 0         259   2000_01_SF_ATL    2000       REG     1  2000-09-03  Sunday
# 1         260  2000_01_JAX_CLE    2000       REG     1  2000-09-03  Sunday
# 2         261   2000_01_IND_KC    2000       REG     1  2000-09-03  Sunday
# 3         262  2000_01_CHI_MIN    2000       REG     1  2000-09-03  Sunday
# 4         263    2000_01_TB_NE    2000       REG     1  2000-09-03  Sunday
#
#   gametime away_team  away_score  ... ewma_passing_offense_away  \
# 0    13:00        SF          28  ...                  0.085402
# 1    13:00       JAX          27  ...                  0.102550
# 2    13:00       IND          27  ...                  0.055958
# 3    13:00       CHI          27  ...                 -0.079538
# 4    13:00        TB          21  ...                 -0.130162
#
#    ewma_dynamic_window_passing_offense_away epa_rushing_defense_away  \
# 0                                  0.085402                -0.363727
# 1                                  0.102550                 0.204234
# 2                                  0.055958                -0.311451
# 3                                 -0.079538                 0.283000
# 4                                 -0.130162                -0.254412
#
#    epa_shifted_rushing_defense_away  ewma_rushing_defense_away  \
# 0                         -0.292738                  -0.101883
# 1                          0.034425                  -0.208297
# 2                         -0.027761                  -0.049084
# 3                         -0.130394                  -0.057451
# 4                         -0.233736                  -0.195255
#
#    ewma_dynamic_window_rushing_defense_away  epa_passing_defense_away  \
# 0                                 -0.101883                  0.329638
# 1                                 -0.208297                 -0.216874
# 2                                 -0.049084                 -0.090687
# 3                                 -0.057451                  0.124496
# 4                                 -0.195255                 -0.188796
#
#    epa_shifted_passing_defense_away ewma_passing_defense_away  \
# 0                          0.407593                  0.260712
# 1                         -0.131932                 -0.147295
# 2                         -0.078516                  0.092024
# 3                          0.365886                  0.105317
# 4                         -0.073635                 -0.222231
#
#   ewma_dynamic_window_passing_defense_away
# 0                                 0.260712
# 1                                -0.147295
# 2                                 0.092024
# 3                                 0.105317
# 4                                -0.222231
#
# [5 rows x 78 columns]

# %%
df.to_csv('nfl_mdf.csv')
